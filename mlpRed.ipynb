# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd

# %%
#NORMALIZADA
#df = pd.read_csv("dataset/dfRed.csv", sep = ';')

#ORIGINAL
df = pd.read_csv("dataset/winequality-red.csv", sep = ';')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

colunas = df.columns

#PADRONIZAR
scaler_standard = StandardScaler()
dfPadronizado = pd.DataFrame(scaler_standard.fit_transform(df), columns = colunas)

#NORMALIZAR
scaler_minMax = MinMaxScaler()
dfNormalizado  = pd.DataFrame(scaler_minMax.fit_transform(dfPadronizado), columns=colunas)



display(df)
display(dfPadronizado)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1         -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2         -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3          1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# ...             ...               ...          ...             ...        ...
# 1594      -1.217796          0.403229    -0.980669       -0.382271   0.053845
# 1595      -1.390155          0.123905    -0.877968       -0.240375  -0.541259
# 1596      -1.160343         -0.099554    -0.723916       -0.169427  -0.243707
# 1597      -1.390155          0.654620    -0.775267       -0.382271  -0.264960
# 1598      -1.332702         -1.216849     1.021999        0.752894  -0.434990
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.466193             -0.379133  0.558274  1.288643
# 1                0.872638              0.624363  0.028261 -0.719933
# 2               -0.083669              0.229047  0.134264 -0.331177
# 3                0.107592              0.411500  0.664277 -0.979104
# 4               -0.466193             -0.379133  0.558274  1.288643
# ...                   ...                   ...       ...       ...
# 1594             1.542054             -0.075043 -0.978765  0.899886
# 1595             2.211469              0.137820 -0.862162  1.353436
# 1596             1.255161             -0.196679 -0.533554  0.705508
# 1597             1.542054             -0.075043 -0.676657  1.677400
# 1598             0.203223             -0.135861 -0.666057  0.511130
#
#       sulphates   alcohol   quality
# 0     -0.579207 -0.960246 -0.787823
# 1      0.128950 -0.584777 -0.787823
# 2     -0.048089 -0.584777 -0.787823
# 3     -0.461180 -0.584777  0.450848
# 4     -0.579207 -0.960246 -0.787823
# ...         ...       ...       ...
# 1594  -0.461180  0.072294 -0.787823
# 1595   0.601055  0.729364  0.450848
# 1596   0.542042  0.541630  0.450848
# 1597   0.305990 -0.209308 -0.787823
# 1598   0.010924  0.541630  0.450848
#
# [1599 rows x 12 columns]

# %%
X = df.drop('quality', axis=1).values  # Features são todas as colunas exceto a coluna 'quality'
y = df['quality'].values  # TARGET TEM Q SER EM INTEIRO
display(y)

a = dfPadronizado['quality'].values
display(a)
# Out:
# array([5, 5, 5, ..., 6, 5, 6])
# array([-0.78782264, -0.78782264, -0.78782264, ...,  0.45084835,
#        -0.78782264,  0.45084835])

# %%
# Dividir os dados em conjuntos de treinamento e teste
# X_train: Conjunto de features para treinamento
# X_test: Conjunto de features para teste
# y_train: Conjunto de targets para treinamento
# y_test: Conjunto de targets para teste

# random_state: Semente usada pelo gerador de números aleatórios 
# para garantir reprodutibilidade nos resultados. 
# O valor "1" é usado aqui como exemplo, mas você pode usar qualquer 
# número inteiro ou deixar esse parâmetro em branco para obter uma semente aleatória.

# test_size: Tamanho do conjunto de teste em relação ao conjunto total de dados. 
# Nesse exemplo, o conjunto de teste terá 75% dos dados e o conjunto de treinamento terá 25%. 
# O valor deve ser um número entre 0 e 1, representando a proporção do 
# conjunto de teste em relação ao conjunto total de dados.

X_train, X_test, y_train, y_test= train_test_split(X, y, random_state=1, test_size=.25)

print('Quantidade de dados de treino:', X_train.shape) 
print('Quantidade de dados de teste:', X_test.shape) 

print(y_train)
# Out:
# Quantidade de dados de treino: (1199, 11)
# Quantidade de dados de teste: (400, 11)
# [5 4 5 ... 6 6 8]

# %%
clf = MLPClassifier(
    verbose=True,      # Se True, o modelo exibirá informações sobre o processo de treinamento.
    max_iter=500,      # Número máximo de iterações (épocas) para o treinamento do modelo.
    tol=0.0000001,     # Tolerância para critério de parada. O treinamento para se a perda (loss) não diminuir por pelo menos tol nas últimas duas épocas.
    activation="relu", # Função de ativação a ser usada nas camadas ocultas. "relu" representa a função retificação linear (ReLU).
    solver='adam'      # O otimizador usado para ajustar os pesos do modelo. "adam" representa o otimizador Adam.
).fit(X_train, y_train)
# Out:
# Iteration 1, loss = 5.83282733
# Iteration 2, loss = 2.80250077
# Iteration 3, loss = 2.55198869
# Iteration 4, loss = 2.01876348
# Iteration 5, loss = 1.85566521
# Iteration 6, loss = 1.56267548
# Iteration 7, loss = 1.47683585
# Iteration 8, loss = 1.35594050
# Iteration 9, loss = 1.30051565
# Iteration 10, loss = 1.27253047
# Iteration 11, loss = 1.23989116
# Iteration 12, loss = 1.21595681
# Iteration 13, loss = 1.20516144
# Iteration 14, loss = 1.19810009
# Iteration 15, loss = 1.18348052
# Iteration 16, loss = 1.17535203
# Iteration 17, loss = 1.16647152
# Iteration 18, loss = 1.16172758
# Iteration 19, loss = 1.15621221
# Iteration 20, loss = 1.15074990
# Iteration 21, loss = 1.15187420
# Iteration 22, loss = 1.14783320
# Iteration 23, loss = 1.14016278
# Iteration 24, loss = 1.13948005
# Iteration 25, loss = 1.13250487
# Iteration 26, loss = 1.12877351
# Iteration 27, loss = 1.12561226
# Iteration 28, loss = 1.12166153
# Iteration 29, loss = 1.11838441
# Iteration 30, loss = 1.11654580
# Iteration 31, loss = 1.11310924
# Iteration 32, loss = 1.11950254
# Iteration 33, loss = 1.11975400
# Iteration 34, loss = 1.12427423
# Iteration 35, loss = 1.11841755
# Iteration 36, loss = 1.10955958
# Iteration 37, loss = 1.11328056
# Iteration 38, loss = 1.11372501
# Iteration 39, loss = 1.10856112
# Iteration 40, loss = 1.10654574
# Iteration 41, loss = 1.09725933
# Iteration 42, loss = 1.09225777
# Iteration 43, loss = 1.08803413
# Iteration 44, loss = 1.08650245
# Iteration 45, loss = 1.08697966
# Iteration 46, loss = 1.08539189
# Iteration 47, loss = 1.08623700
# Iteration 48, loss = 1.08697888
# Iteration 49, loss = 1.07790606
# Iteration 50, loss = 1.08215348
# Iteration 51, loss = 1.07921645
# Iteration 52, loss = 1.07705622
# Iteration 53, loss = 1.07620936
# Iteration 54, loss = 1.06761907
# Iteration 55, loss = 1.06426048
# Iteration 56, loss = 1.07806293
# Iteration 57, loss = 1.06680137
# Iteration 58, loss = 1.06137858
# Iteration 59, loss = 1.06177406
# Iteration 60, loss = 1.05951856
# Iteration 61, loss = 1.05690608
# Iteration 62, loss = 1.05461376
# Iteration 63, loss = 1.05418572
# Iteration 64, loss = 1.06019876
# Iteration 65, loss = 1.05992734
# Iteration 66, loss = 1.04680794
# Iteration 67, loss = 1.04486959
# Iteration 68, loss = 1.04707465
# Iteration 69, loss = 1.04638119
# Iteration 70, loss = 1.04570367
# Iteration 71, loss = 1.03832656
# Iteration 72, loss = 1.03818147
# Iteration 73, loss = 1.03657444
# Iteration 74, loss = 1.03465524
# Iteration 75, loss = 1.03519715
# Iteration 76, loss = 1.03233882
# Iteration 77, loss = 1.03083980
# Iteration 78, loss = 1.02993985
# Iteration 79, loss = 1.02761680
# Iteration 80, loss = 1.02845692
# Iteration 81, loss = 1.02577444
# Iteration 82, loss = 1.02756732
# Iteration 83, loss = 1.02584429
# Iteration 84, loss = 1.02342737
# Iteration 85, loss = 1.01930554
# Iteration 86, loss = 1.01790314
# Iteration 87, loss = 1.01848212
# Iteration 88, loss = 1.01306832
# Iteration 89, loss = 1.01513330
# Iteration 90, loss = 1.01599276
# Iteration 91, loss = 1.01319784
# Iteration 92, loss = 1.00891569
# Iteration 93, loss = 1.00875355
# Iteration 94, loss = 1.00480637
# Iteration 95, loss = 1.00301668
# Iteration 96, loss = 1.00100794
# Iteration 97, loss = 0.99966886
# Iteration 98, loss = 1.00122765
# Iteration 99, loss = 0.99913282
# Iteration 100, loss = 0.99959524
# Iteration 101, loss = 1.00420148
# Iteration 102, loss = 0.99448574
# Iteration 103, loss = 0.99103511
# Iteration 104, loss = 0.98900764
# Iteration 105, loss = 0.98881511
# Iteration 106, loss = 0.98883486
# Iteration 107, loss = 0.98812239
# Iteration 108, loss = 0.98779478
# Iteration 109, loss = 0.98924815
# Iteration 110, loss = 0.98712823
# Iteration 111, loss = 0.99181485
# Iteration 112, loss = 0.98312608
# Iteration 113, loss = 0.98341146
# Iteration 114, loss = 0.98499935
# Iteration 115, loss = 0.98069818
# Iteration 116, loss = 0.98043788
# Iteration 117, loss = 0.98050508
# Iteration 118, loss = 0.98042285
# Iteration 119, loss = 0.98044021
# Iteration 120, loss = 0.97733505
# Iteration 121, loss = 0.97593130
# Iteration 122, loss = 0.97233100
# Iteration 123, loss = 0.97583620
# Iteration 124, loss = 0.97267918
# Iteration 125, loss = 0.96843708
# Iteration 126, loss = 0.96660714
# Iteration 127, loss = 0.96948443
# Iteration 128, loss = 0.96893146
# Iteration 129, loss = 0.96814357
# Iteration 130, loss = 0.96735390
# Iteration 131, loss = 0.96672015
# Iteration 132, loss = 0.96245058
# Iteration 133, loss = 0.97129131
# Iteration 134, loss = 0.96235054
# Iteration 135, loss = 0.96204993
# Iteration 136, loss = 0.96137240
# Iteration 137, loss = 0.96187527
# Iteration 138, loss = 0.95859794
# Iteration 139, loss = 0.96624180
# Iteration 140, loss = 0.96645572
# Iteration 141, loss = 0.96013998
# Iteration 142, loss = 0.96436336
# Iteration 143, loss = 0.95659375
# Iteration 144, loss = 0.95801070
# Iteration 145, loss = 0.96086510
# Iteration 146, loss = 0.95930545
# Iteration 147, loss = 0.96035531
# Iteration 148, loss = 0.95108982
# Iteration 149, loss = 0.95165713
# Iteration 150, loss = 0.95778117
# Iteration 151, loss = 0.94815129
# Iteration 152, loss = 0.95961639
# Iteration 153, loss = 0.96266517
# Iteration 154, loss = 0.96147817
# Iteration 155, loss = 0.95809950
# Iteration 156, loss = 0.96882059
# Iteration 157, loss = 0.95200670
# Iteration 158, loss = 0.94547623
# Iteration 159, loss = 0.94299970
# Iteration 160, loss = 0.94333061
# Iteration 161, loss = 0.95467552
# Iteration 162, loss = 0.95560902
# Iteration 163, loss = 0.95050782
# Iteration 164, loss = 0.95717388
# Iteration 165, loss = 0.94619902
# Iteration 166, loss = 0.94430982
# Iteration 167, loss = 0.94242342
# Iteration 168, loss = 0.94151978
# Iteration 169, loss = 0.93678481
# Iteration 170, loss = 0.93821106
# Iteration 171, loss = 0.93962227
# Iteration 172, loss = 0.93482774
# Iteration 173, loss = 0.93516692
# Iteration 174, loss = 0.94462823
# Iteration 175, loss = 0.94676314
# Iteration 176, loss = 0.93600852
# Iteration 177, loss = 0.93641172
# Iteration 178, loss = 0.93785592
# Iteration 179, loss = 0.93946670
# Iteration 180, loss = 0.93090260
# Iteration 181, loss = 0.93013975
# Iteration 182, loss = 0.93474193
# Iteration 183, loss = 0.92951209
# Iteration 184, loss = 0.93532491
# Iteration 185, loss = 0.93895009
# Iteration 186, loss = 0.93260207
# Iteration 187, loss = 0.93071707
# Iteration 188, loss = 0.92669628
# Iteration 189, loss = 0.92922156
# Iteration 190, loss = 0.92917117
# Iteration 191, loss = 0.93450110
# Iteration 192, loss = 0.93304592
# Iteration 193, loss = 0.93218423
# Iteration 194, loss = 0.93651089
# Iteration 195, loss = 0.92069367
# Iteration 196, loss = 0.92599008
# Iteration 197, loss = 0.92333446
# Iteration 198, loss = 0.92308509
# Iteration 199, loss = 0.93299454
# Iteration 200, loss = 0.93145575
# Iteration 201, loss = 0.92720510
# Iteration 202, loss = 0.92374030
# Iteration 203, loss = 0.91906041
# Iteration 204, loss = 0.91952852
# Iteration 205, loss = 0.92285066
# Iteration 206, loss = 0.92401470
# Iteration 207, loss = 0.92055455
# Iteration 208, loss = 0.92011141
# Iteration 209, loss = 0.91545009
# Iteration 210, loss = 0.92891737
# Iteration 211, loss = 0.91929014
# Iteration 212, loss = 0.91840629
# Iteration 213, loss = 0.91585088
# Iteration 214, loss = 0.91644262
# Iteration 215, loss = 0.91890330
# Iteration 216, loss = 0.91649611
# Iteration 217, loss = 0.92122835
# Iteration 218, loss = 0.91694679
# Iteration 219, loss = 0.92546508
# Iteration 220, loss = 0.92004561
# Training loss did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.

# %%
clf.predict(X_test)
accuracy_score(clf.predict(X_test), y_test)

## ACURACIA
# Out:
# 0.635

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier

# Supondo que você já tenha criado e ajustado (fit) o modelo MLPClassifier e atribuído a 'clf'

# Imprimir o número de iterações
print(clf.n_iter_)

# Criar os arrays para plotagem
x = np.arange(clf.n_iter_)
y = clf.loss_curve_

# Plotar a curva de perda (loss curve)
plt.plot(x, y)
plt.style.use("ggplot")
plt.xlabel('Número de Iterações').set_color('black')
plt.ylabel('Perda (Loss)').set_color('black')
plt.tick_params(colors='black', which='both')

plt.title('Curva de Perda (Loss Curve)')
plt.savefig('graficos/curvadeperdaRed', dpi=300, bbox_inches = "tight")
plt.show()
# Out:
# 220
